# %% [markdown]
# ## Marjan Farsi - Group 12 - Storm Dataset - Group Project Task 2 - Dist. Computing

# %% [markdown]
# ## Query : Map or group by state (or region) to compare which states see more tornadoes more severe tornadoes.

# %%
#!pip install google-cloud-storage

# %% [markdown]
# ### Create small dataset with 5000 record (one time run)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark = SparkSession.builder.appName("StormApp1").getOrCreate()

# # Load as Spark DataFrame
df = spark.read.csv("storm_g2020.csv", header=True, inferSchema=True)

# Get top 5000 records
#df_small = init_df.limit(5000)

#df_small.coalesce(1).write.csv("top5000_temp", header=True, mode="overwrite")

# %% [markdown]
# ### Data Cleansing -> Replace null values in associated columns ("EVENT_TYPE" , "STATE",  "TOR_F_SCALE" ) with safe values for each column

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when, regexp_replace, avg, count, round, desc, lit

# Clean EVENT_TYPE
df = df.withColumn(
    "EVENT_TYPE",
    when(col("EVENT_TYPE").isNull(), lit("Unknown")).otherwise(col("EVENT_TYPE"))
)

# Clean STATE
df = df.withColumn(
    "STATE",
    when(col("STATE").isNull(), lit("Unknown")).otherwise(col("STATE"))
)

# Clean TOR_F_SCALE (keep categorical!)
df = df.withColumn(
    "TOR_F_SCALE",
    when(col("TOR_F_SCALE").isNull(), lit("EF0")).otherwise(col("TOR_F_SCALE"))
)

df.show()
# Out:
# +---------------+---------+----------+-------------+-------+--------+----------+--------+--------+----------+----+----------+-----------------+-------+-------+----------+---+------------------+-----------+------------------+---------------+-----------------+-------------+---------------+---------------+------------+---------------+---------+--------------+-----------+--------+-----------+----------+---------+-------------+------------------+-----------------+-----------------+-----------+-------------+-------------------+---------+-----------+-------------------+---------+---------+-------+---------+--------------------+--------------------+-----------+
# |BEGIN_YEARMONTH|BEGIN_DAY|BEGIN_TIME|END_YEARMONTH|END_DAY|END_TIME|EPISODE_ID|EVENT_ID|   STATE|STATE_FIPS|YEAR|MONTH_NAME|       EVENT_TYPE|CZ_TYPE|CZ_FIPS|   CZ_NAME|WFO|   BEGIN_DATE_TIME|CZ_TIMEZONE|     END_DATE_TIME|INJURIES_DIRECT|INJURIES_INDIRECT|DEATHS_DIRECT|DEATHS_INDIRECT|DAMAGE_PROPERTY|DAMAGE_CROPS|         SOURCE|MAGNITUDE|MAGNITUDE_TYPE|FLOOD_CAUSE|CATEGORY|TOR_F_SCALE|TOR_LENGTH|TOR_WIDTH|TOR_OTHER_WFO|TOR_OTHER_CZ_STATE|TOR_OTHER_CZ_FIPS|TOR_OTHER_CZ_NAME|BEGIN_RANGE|BEGIN_AZIMUTH|     BEGIN_LOCATION|END_RANGE|END_AZIMUTH|       END_LOCATION|BEGIN_LAT|BEGIN_LON|END_LAT|  END_LON|   EPISODE_NARRATIVE|     EVENT_NARRATIVE|DATA_SOURCE|
# +---------------+---------+----------+-------------+-------+--------+----------+--------+--------+----------+----+----------+-----------------+-------+-------+----------+---+------------------+-----------+------------------+---------------+-----------------+-------------+---------------+---------------+------------+---------------+---------+--------------+-----------+--------+-----------+----------+---------+-------------+------------------+-----------------+-----------------+-----------+-------------+-------------------+---------+-----------+-------------------+---------+---------+-------+---------+--------------------+--------------------+-----------+
# |         202006|       24|      1620|       202006|     24|    1620|  149684.0|  902190| GEORGIA|      13.0|2020|      June|Thunderstorm Wind|      C|    321|     WORTH|TAE|24-JUN-20 16:20:00|      EST-5|24-JUN-20 16:20:00|              0|                0|            0|              0|          0.00K|       0.00K|911 Call Center|     50.0|            EG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|            W|              DOLES|      1.0|          W|              DOLES|     31.7|   -83.89|   31.7|   -83.89|As is typical dur...|A power line was ...|        CSV|
# |         202006|       20|      1930|       202006|     20|    1930|  149048.0|  898391|  KANSAS|      20.0|2020|      June|             Hail|      C|    137|    NORTON|GLD|20-JUN-20 19:30:00|      CST-6|20-JUN-20 19:30:00|              0|                0|            0|              0|           NULL|        NULL|         Public|      1.0|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        8.0|           SE|            CALVERT|      8.0|         SE|            CALVERT|  39.7571| -99.6684|39.7571| -99.6684|Supercells in sma...|Penny to quarter ...|        CSV|
# |         202006|        3|      1550|       202006|      3|    1550|  149149.0|  899120|  KANSAS|      20.0|2020|      June|             Hail|      C|     23|  CHEYENNE|GLD|03-JUN-20 15:50:00|      CST-6|03-JUN-20 15:50:00|              0|                0|            0|              0|           NULL|        NULL|Trained Spotter|     0.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|       14.0|           NW|         ST FRANCIS|     14.0|         NW|         ST FRANCIS|  39.9137|-101.9753|39.9137|-101.9753|Thunderstorms for...|Dime to penny siz...|        CSV|
# |         202006|       19|      1900|       202006|     19|    1900|  149046.0|  898383|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    193|    THOMAS|GLD|19-JUN-20 19:00:00|      CST-6|19-JUN-20 19:00:00|              0|                0|            0|              0|           NULL|        NULL|911 Call Center|     52.0|            EG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        2.0|          SSE|           BREWSTER|      2.0|        SSE|           BREWSTER|    39.34|  -101.37|  39.34|  -101.37|Thunderstorms mov...|Officer reported ...|        CSV|
# |         202006|       20|      1900|       202006|     20|    1900|  149048.0|  898388|  KANSAS|      20.0|2020|      June|             Hail|      C|    137|    NORTON|GLD|20-JUN-20 19:00:00|      CST-6|20-JUN-20 19:00:00|              0|                0|            0|              0|           NULL|        NULL|       CoCoRaHS|     1.25|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|           SE|   NORTON MUNI ARPT|      1.0|         SE|   NORTON MUNI ARPT|    39.84|   -99.89|  39.84|   -99.89|Supercells in sma...|                NULL|        CSV|
# |         202006|       20|      1837|       202006|     20|    1837|  149048.0|  899127|  KANSAS|      20.0|2020|      June|             Hail|      C|    137|    NORTON|GLD|20-JUN-20 18:37:00|      CST-6|20-JUN-20 18:37:00|              0|                0|            0|              0|           NULL|        NULL|         Public|     0.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        6.0|            N|   NORTON MUNI ARPT|      6.0|          N|   NORTON MUNI ARPT|  39.9397| -99.8877|39.9397| -99.8877|Supercells in sma...|Small hail up to ...|        CSV|
# |         202006|       23|      1511|       202006|     23|    1511|  149138.0|  899011|COLORADO|       8.0|2020|      June|             Hail|      C|     17|  CHEYENNE|GLD|23-JUN-20 15:11:00|      MST-7|23-JUN-20 15:11:00|              0|                0|            0|              0|           NULL|        NULL|Trained Spotter|     0.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        6.0|          ESE|         KIT CARSON|      6.0|        ESE|         KIT CARSON|  38.7204|-102.6783|38.7204|-102.6783|Isolated thunders...|Trained spotter r...|        CSV|
# |         202006|       26|      1830|       202006|     26|    1830|  149530.0|  901352|COLORADO|       8.0|2020|      June|             Hail|      C|    125|      YUMA|GLD|26-JUN-20 18:30:00|      MST-7|26-JUN-20 18:30:00|              0|                0|            0|              0|           NULL|        NULL|         Public|     0.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        3.0|          ESE|             VERNON|      3.0|        ESE|             VERNON|  39.9134|-102.2277|39.9134|-102.2277|A line of thunder...|Pea to dime size ...|        CSV|
# |         202006|       26|      1845|       202006|     26|    1850|  149530.0|  901350|COLORADO|       8.0|2020|      June|             Hail|      C|    125|      YUMA|GLD|26-JUN-20 18:45:00|      MST-7|26-JUN-20 18:50:00|              0|                0|            0|              0|           NULL|        NULL|         Public|     1.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        3.0|          WSW|         BEECHER IS|      3.0|        WSW|         BEECHER IS|    39.86|  -102.18|  39.86|  -102.18|A line of thunder...|Pea to quarter si...|        CSV|
# |         202006|        9|      1344|       202006|      9|    1344|  149984.0|  904300|  KANSAS|      20.0|2020|      June|        High Wind|      Z|      2|   RAWLINS|GLD|09-JUN-20 13:44:00|      CST-6|09-JUN-20 13:44:00|              0|                0|            0|              0|          0.00K|       0.00K|        Mesonet|     59.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|       NULL|         NULL|               NULL|     NULL|       NULL|               NULL|     NULL|     NULL|   NULL|     NULL|Unseasonably stro...|This was measured...|        CSV|
# |         202006|        6|      1820|       202006|      6|    1820|  149595.0|  901613|COLORADO|       8.0|2020|      June|Thunderstorm Wind|      C|     63|KIT CARSON|GLD|06-JUN-20 18:20:00|      MST-7|06-JUN-20 18:20:00|              0|                0|            0|              0|           NULL|        NULL|Law Enforcement|     50.0|            EG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        5.0|          WSW|    BURLINGTON ARPT|      5.0|        WSW|    BURLINGTON ARPT|  39.2942| -102.372|39.2942| -102.372|A high wind gust ...|Visibility fell t...|        CSV|
# |         202006|       27|      2048|       202006|     27|    2048|  149052.0|  898414|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    193|    THOMAS|GLD|27-JUN-20 20:48:00|      CST-6|27-JUN-20 20:48:00|              0|                0|            0|              0|           NULL|        NULL|Trained Spotter|     52.0|            EG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        5.0|            N|           BREWSTER|      5.0|          N|           BREWSTER|  39.4468|-101.3711|39.4468|-101.3711|Storms formed in ...|Trained spotter r...|        CSV|
# |         202006|       27|      2145|       202006|     27|    2145|  149052.0|  898415|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    153|   RAWLINS|GLD|27-JUN-20 21:45:00|      CST-6|27-JUN-20 21:45:00|              0|                0|            0|              0|           NULL|        NULL|        Mesonet|     51.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        8.0|          WNW|            HERNDON|      8.0|        WNW|            HERNDON|    39.96|   -100.9|  39.96|   -100.9|Storms formed in ...|                NULL|        CSV|
# |         202006|       27|        36|       202006|     27|      36|  149531.0|  901355|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|     65|    GRAHAM|GLD|27-JUN-20 00:36:00|      CST-6|27-JUN-20 00:36:00|              0|                0|            0|              0|           NULL|        NULL|           ASOS|     56.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|            S|(HLC)HILL CITY MUNI|      1.0|          S|(HLC)HILL CITY MUNI|    39.37|   -99.83|  39.37|   -99.83|A line of thunder...|KHLC ASOS reporte...|        CSV|
# |         202006|       28|       102|       202006|     28|     102|  149052.0|  898416|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    109|     LOGAN|GLD|28-JUN-20 01:02:00|      CST-6|28-JUN-20 01:02:00|              0|                0|            0|              0|           NULL|        NULL|           AWOS|     56.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|            S|   OAKLEY MUNI ARPT|      1.0|          S|   OAKLEY MUNI ARPT|    39.11|  -100.82|  39.11|  -100.82|Storms formed in ...|There was also a ...|        CSV|
# |         202006|       27|      2127|       202006|     27|    2127|  149052.0|  899128|  KANSAS|      20.0|2020|      June|             Hail|      C|    109|     LOGAN|GLD|27-JUN-20 21:27:00|      CST-6|27-JUN-20 21:27:00|              0|                0|            0|              0|           NULL|        NULL|         Public|     0.75|          NULL|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|            W|             OAKLEY|      1.0|          W|             OAKLEY|    39.13|-100.8664|  39.13|-100.8664|Storms formed in ...|Dime to penny siz...|        CSV|
# |         202006|       26|      2006|       202006|     26|    2006|  149531.0|  901353|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    181|   SHERMAN|GLD|26-JUN-20 20:06:00|      MST-7|26-JUN-20 20:06:00|              0|                0|            0|              0|           NULL|        NULL|           ASOS|     51.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        1.0|           SE|      GOODLAND ARPT|      1.0|         SE|      GOODLAND ARPT|    39.36|  -101.69|  39.36|  -101.69|A line of thunder...|KGLD ASOS reporte...|        CSV|
# |         202006|       26|      2040|       202006|     26|    2040|  149531.0|  901354|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|    199|   WALLACE|GLD|26-JUN-20 20:40:00|      MST-7|26-JUN-20 20:40:00|              0|                0|            0|              0|           NULL|        NULL|        Mesonet|     52.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        4.0|           NE|        SHARON SPGS|      4.0|         NE|        SHARON SPGS|    38.92|  -101.67|  38.92|  -101.67|A line of thunder...|Mesonet station K...|        CSV|
# |         202006|       27|        20|       202006|     27|      20|  149531.0|  901358|  KANSAS|      20.0|2020|      June|Thunderstorm Wind|      C|     65|    GRAHAM|GLD|27-JUN-20 00:20:00|      CST-6|27-JUN-20 00:20:00|              0|                0|            0|              0|         15.00K|        NULL|         Public|     78.0|            EG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|       11.0|            E|           ST PETER|     11.0|          E|           ST PETER|  39.1802| -99.8663|39.1802| -99.8663|A line of thunder...|Pictures received...|        CSV|
# |         202006|       27|      1840|       202006|     27|    1840|  149051.0|  898405|COLORADO|       8.0|2020|      June|Thunderstorm Wind|      C|     17|  CHEYENNE|GLD|27-JUN-20 18:40:00|      MST-7|27-JUN-20 18:40:00|              0|                0|            0|              0|           NULL|        NULL|        Mesonet|     56.0|            MG|       NULL|    NULL|        EF0|      NULL|     NULL|         NULL|              NULL|             NULL|             NULL|        2.0|           NW|            CARLTON|      2.0|         NW|            CARLTON|    38.85|  -102.13|  38.85|  -102.13|Storms formed in ...|                NULL|        CSV|
# +---------------+---------+----------+-------------+-------+--------+----------+--------+--------+----------+----+----------+-----------------+-------+-------+----------+---+------------------+-----------+------------------+---------------+-----------------+-------------+---------------+---------------+------------+---------------+---------+--------------+-----------+--------+-----------+----------+---------+-------------+------------------+-----------------+-----------------+-----------+-------------+-------------------+---------+-----------+-------------------+---------+---------+-------+---------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ### We produce two maps (tables):
#
# ### Tornado Frequency Map
#
# → Which states see more tornadoes?
#
# ### Tornado Severity Map
#
# → Which states see more severe tornadoes (EF3–EF5)?
#
# ### Then we produce a combined summary.

# %%
from pyspark.sql.functions import col, count, avg, desc
from pyspark.sql.functions import round

# Filter only tornado events
tornado_df = df.filter(col("EVENT_TYPE") == "Tornado")

#Count tornado by State
state_tornado_frequency = (
    tornado_df.groupBy("STATE")
              .agg(count("*").alias("tornado_count"))
              .orderBy(desc("tornado_count"))
)

# States with more severe tornados: Severe tornadoes are EF3, EF4, EF5

severe_df = tornado_df.filter(col("TOR_F_SCALE").isin("EF3","EF4","EF5"))

state_severe_frequency = (
    severe_df.groupBy("STATE")
             .agg(count("*").alias("severe_tornado_count"))
             .orderBy(desc("severe_tornado_count"))
)

# Combine Both Metrics (tabeles): Frequency + Severity
summary = (
    state_tornado_frequency.join(state_severe_frequency, on="STATE", how="left")
                           .fillna(0)   # fill states with no EF3+ tornadoes
                           .orderBy(desc("tornado_count"))
)

# In the table below, 50 top states with both, more number of tornado and more severe tornado in descending order are displayed (state with most number of Tornado and most severe one is on the top)
summary.show(50, truncate=False)
# Out:
# +--------------------+-------------+--------------------+
# |STATE               |tornado_count|severe_tornado_count|
# +--------------------+-------------+--------------------+
# |TEXAS               |663          |24                  |
# |MISSISSIPPI         |660          |24                  |
# |ILLINOIS            |607          |6                   |
# |ALABAMA             |543          |17                  |
# |OKLAHOMA            |505          |16                  |
# |IOWA                |477          |13                  |
# |FLORIDA             |365          |5                   |
# |GEORGIA             |348          |10                  |
# |LOUISIANA           |337          |7                   |
# |MISSOURI            |334          |20                  |
# |NEBRASKA            |314          |7                   |
# |ARKANSAS            |285          |11                  |
# |MINNESOTA           |282          |2                   |
# |TENNESSEE           |281          |17                  |
# |OHIO                |265          |2                   |
# |KENTUCKY            |259          |15                  |
# |KANSAS              |258          |9                   |
# |INDIANA             |247          |7                   |
# |COLORADO            |231          |2                   |
# |SOUTH CAROLINA      |211          |10                  |
# |WISCONSIN           |202          |1                   |
# |NORTH CAROLINA      |175          |6                   |
# |PENNSYLVANIA        |128          |2                   |
# |SOUTH DAKOTA        |111          |1                   |
# |MICHIGAN            |92           |1                   |
# |NORTH DAKOTA        |77           |0                   |
# |NEW YORK            |74           |1                   |
# |VIRGINIA            |71           |1                   |
# |MARYLAND            |56           |0                   |
# |NEW MEXICO          |55           |0                   |
# |NEW JERSEY          |41           |1                   |
# |WYOMING             |34           |0                   |
# |CALIFORNIA          |34           |0                   |
# |ARIZONA             |31           |0                   |
# |WEST VIRGINIA       |27           |0                   |
# |CONNECTICUT         |20           |0                   |
# |MASSACHUSETTS       |19           |0                   |
# |MONTANA             |17           |0                   |
# |WASHINGTON          |13           |0                   |
# |OREGON              |13           |0                   |
# |DELAWARE            |13           |1                   |
# |UTAH                |8            |0                   |
# |NEW HAMPSHIRE       |7            |0                   |
# |RHODE ISLAND        |7            |0                   |
# |IDAHO               |7            |0                   |
# |PUERTO RICO         |5            |0                   |
# |VERMONT             |4            |0                   |
# |NEVADA              |3            |0                   |
# |MAINE               |2            |0                   |
# |DISTRICT OF COLUMBIA|2            |0                   |
# +--------------------+-------------+--------------------+
# only showing top 50 rows
